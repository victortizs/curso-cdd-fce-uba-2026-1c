# %% [raw]
# ---
# title: "04: Transformación y unión"
# subtitle: "Presencial"
# author: "Victor Adrian"
# format: html
# toc: true
# output-file: "clase-04-20260331-jupytext.html"
# code-overflow: wrap
# date: "March 31, 2026"
# date-format: "iso"
# embed-resources: true
# ---

# %% [markdown]
# ## Intro

# %% [markdown]
# En proceso...
